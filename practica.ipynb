# %%
#escribir un programa que acepte el porcentaje de un alumno y evalue el grado de acuerdo al siguiente criterio:
#calificacion Grado 
# >90           A
# >80 y <=90    B
# >=60 y <=80   C
#menor a 60     D

# %%
porcentaje = int(input("escribe el porcentaje"))
if porcentaje>90:
    
    print("porcentaje es igual A")
elif porcentaje<80 and porcentaje<=90:
    print("el porcentaje es igual B")
elif porcentaje>=60 and porcentaje<=80:
    print("el porcentaje es igual C")
else:
    print("porcentaje es igual D")
# Out:
# escribe el porcentaje 110
# porcentaje es igual A

# %%
#escribir un programa que capture el precio de una bicicleta y muestre los impuestos que debe pagar siguiendo los siguientes criterios:
#costo   impuesto
#>10000  15%
#>50000 y <=100000 10%
#50000     5%

# %%
precio = int(input("escribe el precio de la bicicleta"))
if precio>100000:
    print("impuesto igual a",precio *.15)
elif precio>50000 and precio<=100000:
    print("impuesto igual a" ,precio *.10)
elif precio<=50000:
    print("impuesto igual a",precio*.5)
# Out:
# escribe el precio de la bicicleta 78900
# impuesto igual a 7890.0

# %%
año = int(input("Introduce el año: "))

# Verificación de si el año es bisiesto
if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0):
    print(f"El año {año} es bisiesto.")
else:
    print(f"El año {año} no es bisiesto.")
# Out:
# Introduce el año:  1785
# El año 1785 no es bisiesto.

# %%
dia = int(input("escribe el numero de dia"))
dias_de_la_semana=["lunes" ,"martes" ,"miercoles" ,"jueves" ,"viernes" ,"sabado" ,"domingo"]
print("el dia de la semana es",dias_de_la_semana[dia-1])
# Out:
# escribe el numero de dia 7
# el dia de la semana es domingo

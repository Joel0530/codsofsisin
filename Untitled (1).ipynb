# %%
nombre = input("cual es tu nombre")
apellido = input("cual es tu apellido")
print(nombre[::-1],apellido[::-1])
# Out:
# cual es tu nombre joel
# cual es tu apellido sandoval
# leoj lavodnas

# %%
edad = int(input("cuantos años tienes"))
nombre = input("cual es tu nombre")
print("en cien años tendras:",[edad+100])
# Out:
# cuantos años tienes 15
# cual es tu nombre joel
# en cien años tendras: [115]
